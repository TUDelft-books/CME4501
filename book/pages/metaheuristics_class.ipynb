# %% [markdown]
# # Class exercise: choose yourself!
#
# Solve one of the previous class exercises using metaheuristics!
# - [](./linear_constrained_optimization_class.ipynb)
# - [](./nonlinear_constrained_optimization_class.ipynb)
# - [](./moo_class.ipynb)

# %% [markdown]
# ```{exercise-start} Method
# :label: meta_method
# ```
#
# Let's solve this problem using a metaheuristic!
#
# Click {fa}`rocket` --> {guilabel}`Live Code` to activate live coding on this page!

# %%
import scipy as sp 
import numpy as np

# %%
#YOUR CODE HERE

# %% [markdown]
# ```{exercise-end}
# ```
